# %%
# loading dataset, display the ten first lines(using=nrow or variable.head(10)
# store in a variable called "client_0_bills."

import pandas as pd

data = pd.read_csv(r"C:\Users\josep\OneDrive\Desktop\Datasets\STEG_BILLING_HISTORY.csv", nrows=10)

data

client_0_bills = data

# %%
client_0_bills
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0               0
# 1  train_Client_0   2013-03-29          11       1335667.0               0
# 2  train_Client_0   2015-03-23          11       1335667.0               0
# 3  train_Client_0   2015-07-13          11       1335667.0               0
# 4  train_Client_0   2016-11-17          11       1335667.0               0
# 5  train_Client_0   2017-07-17          11       1335667.0               0
# 6  train_Client_0   2018-12-07          11       1335667.0               0
# 7  train_Client_0   2019-03-19          11       1335667.0               0
# 8  train_Client_0   2011-07-22          11       1335667.0               0
# 9  train_Client_0   2011-11-22          11       1335667.0               0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# ...

# %%
# What is the data type of the 'client_0_bills' variable ?
type(client_0_bills)
# Out:
# pandas.core.frame.DataFrame

# %%
# How many rows and columns do we have in this dataset ?
nos_row, nos_columns = client_0_bills.shape
print(f" The number rows: {nos_row} and columns: {nos_columns}")
# Out:
#  The number rows: 10 and columns: 16

# %%
# How many categorical features are present in the dataset ?

categorical_features = client_0_bills.select_dtypes(include=["object", "category"]).columns
categorical_features
# Out:
# Index(['client_id', 'invoice_date', 'counter_type'], dtype='object')

# %%
len(categorical_features)
# Out:
# 3

# %%
# How much memory space does the dataset consume ?
memory_space = client_0_bills.memory_usage()
memory_space
# Out:
# Index                   132
# client_id                80
# invoice_date             80
# tarif_type               80
# counter_number           80
# counter_statue           80
# counter_code             80
# reading_remarque         80
# counter_coefficient      80
# consommation_level_1     80
# consommation_level_2     80
# consommation_level_3     80
# consommation_level_4     80
# old_index                80
# new_index                80
# months_number            80
# counter_type             80
# dtype: int64

# %%
# Inspect the dataset for potential missing values.

missing_values = client_0_bills.isnull().sum()
missing_values
# Out:
# client_id               0
# invoice_date            0
# tarif_type              0
# counter_number          0
# counter_statue          0
# counter_code            0
# reading_remarque        0
# counter_coefficient     0
# consommation_level_1    0
# consommation_level_2    0
# consommation_level_3    0
# consommation_level_4    0
# old_index               0
# new_index               0
# months_number           0
# counter_type            0
# dtype: int64

# %%
# Select your strategy to handle missing values, and tell us why you had made that choice.

# first, check for any missing values and the percentage of missingness in each column.
# Secondly, replace missing values in numerical columns with mean or median, and in categorical columns with mode or a constant indicating missingness.

# %%
# Run a descriptive analysis on numeric features (columns).

numeric_descriptive_analysis = client_0_bills.describe()
numeric_descriptive_analysis
# Out:
#        tarif_type  counter_number  counter_statue  counter_code  \
# count        10.0            10.0            10.0     10.000000
# mean         11.0       1335667.0             0.0    205.000000
# std           0.0             0.0             0.0      2.108185
# min          11.0       1335667.0             0.0    203.000000
# 25%          11.0       1335667.0             0.0    203.000000
# 50%          11.0       1335667.0             0.0    205.000000
# 75%          11.0       1335667.0             0.0    207.000000
# max          11.0       1335667.0             0.0    207.000000
#
#        reading_remarque  counter_coefficient  consommation_level_1  \
# count         10.000000                 10.0             10.000000
# mean           8.100000                  1.0            580.100000
# std            1.197219                  0.0            444.535575
# min            6.000000                  1.0             82.000000
# ...

# %%
client_0_bills
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0               0
# 1  train_Client_0   2013-03-29          11       1335667.0               0
# 2  train_Client_0   2015-03-23          11       1335667.0               0
# 3  train_Client_0   2015-07-13          11       1335667.0               0
# 4  train_Client_0   2016-11-17          11       1335667.0               0
# 5  train_Client_0   2017-07-17          11       1335667.0               0
# 6  train_Client_0   2018-12-07          11       1335667.0               0
# 7  train_Client_0   2019-03-19          11       1335667.0               0
# 8  train_Client_0   2011-07-22          11       1335667.0               0
# 9  train_Client_0   2011-11-22          11       1335667.0               0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# ...

# %%
# Select the bills records for the client with an id ='train_Client_0', using 2 methods.

# USING THE "loc method"
bills_records_1 = client_0_bills.loc[client_0_bills["client_id"] == "train_Client_0"]
bills_records_1
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0               0
# 1  train_Client_0   2013-03-29          11       1335667.0               0
# 2  train_Client_0   2015-03-23          11       1335667.0               0
# 3  train_Client_0   2015-07-13          11       1335667.0               0
# 4  train_Client_0   2016-11-17          11       1335667.0               0
# 5  train_Client_0   2017-07-17          11       1335667.0               0
# 6  train_Client_0   2018-12-07          11       1335667.0               0
# 7  train_Client_0   2019-03-19          11       1335667.0               0
# 8  train_Client_0   2011-07-22          11       1335667.0               0
# 9  train_Client_0   2011-11-22          11       1335667.0               0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# ...

# %%
# The second method, "Using Boolean"

bills_records_2 = client_0_bills[client_0_bills["client_id"] == "train_Client_0"]
bills_records_2
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0               0
# 1  train_Client_0   2013-03-29          11       1335667.0               0
# 2  train_Client_0   2015-03-23          11       1335667.0               0
# 3  train_Client_0   2015-07-13          11       1335667.0               0
# 4  train_Client_0   2016-11-17          11       1335667.0               0
# 5  train_Client_0   2017-07-17          11       1335667.0               0
# 6  train_Client_0   2018-12-07          11       1335667.0               0
# 7  train_Client_0   2019-03-19          11       1335667.0               0
# 8  train_Client_0   2011-07-22          11       1335667.0               0
# 9  train_Client_0   2011-11-22          11       1335667.0               0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# ...

# %%
# Transform the 'counter_type' feature to a numeric variable using the encoder of your choice.

from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
client_0_bills["counter_type_encoded"] = encoder.fit_transform(client_0_bills["counter_type"])

client_0_bills[["counter_type", "counter_type_encoded"]].head(10)
# Out:
#   counter_type  counter_type_encoded
# 0         ELEC                     0
# 1         ELEC                     0
# 2         ELEC                     0
# 3         ELEC                     0
# 4         ELEC                     0
# 5         ELEC                     0
# 6         ELEC                     0
# 7         ELEC                     0
# 8         ELEC                     0
# 9         ELEC                     0

# %%
# Delete the 'counter_statue' feature from the Dataframe

delete_counter_statue = client_0_bills.drop("counter_statue", axis = 1, inplace = False)
delete_counter_statue
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_code  \
# 0  train_Client_0   2014-03-24          11       1335667.0           203
# 1  train_Client_0   2013-03-29          11       1335667.0           203
# 2  train_Client_0   2015-03-23          11       1335667.0           203
# 3  train_Client_0   2015-07-13          11       1335667.0           207
# 4  train_Client_0   2016-11-17          11       1335667.0           207
# 5  train_Client_0   2017-07-17          11       1335667.0           207
# 6  train_Client_0   2018-12-07          11       1335667.0           207
# 7  train_Client_0   2019-03-19          11       1335667.0           207
# 8  train_Client_0   2011-07-22          11       1335667.0           203
# 9  train_Client_0   2011-11-22          11       1335667.0           203
#
#    reading_remarque  counter_coefficient  consommation_level_1  \
# 0               8.0                    1                    82
# ...
